# %%
import torch as pt
import matplotlib.pyplot as plt

# %% [markdown]
# # Chirp with amplitude - Episode 40

# %%
data_ROM = pt.load("chirp_with_amp/observations_39.pt")
#data_ROM = pt.load("")
data_CFD = pt.load("/home/tanuj/observations_79.pt")
# Out:
# /tmp/ipykernel_81720/3564761250.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data_ROM = pt.load("chirp_with_amp/observations_39.pt")
# ...

# %%
data_ROM[0].keys()
# Out:
# dict_keys(['states', 'actions', 'cx_a', 'cy_a', 'rewards', 'alpha', 'beta'])

# %%
plt.plot(data_ROM[0]["rewards"], label = "ROM")
plt.plot(data_CFD[0]["rewards"], label = "MF")
plt.xlabel("time index")
plt.ylabel("rewards")
plt.legend()
plt.show()

# %%
#plt.plot(data_ROM[0]["cx_a"], label = "ROM")
plt.plot(data_ROM[0]["cx_a"], label = "ROM")
plt.plot(data_CFD[0]["cd"], label = "MF")
plt.xlabel("time index")
plt.ylabel("cx_a")
plt.legend()
plt.show()

# %%
#plt.plot(data_ROM[0]["cy_a"], label = "ROM")
plt.plot(data_ROM[0]["cy_a"], label = "ROM")
plt.plot(data_CFD[0]["cl"], label = "MF")
plt.xlabel("time index")
plt.ylabel("cy_a")
plt.legend()
plt.show()

# %%
plt.plot(data_ROM[0]["actions"], label = "ROM")
plt.plot(data_CFD[0]["actions"], label = "MF")
plt.xlabel("time index")
plt.ylabel("actions")
plt.legend()
plt.show()

# %%
plt.plot(data_ROM[0]["alpha"], label = "ROM")
#plt.plot(data_ROM[1]["alpha"], label = "MF")
plt.plot(data_CFD[0]["alpha"], label = "MF")
plt.xlabel("time index")
plt.ylabel("alpha")
plt.legend()
plt.show()

# %%
plt.plot(data_ROM[0]["beta"], label = "ROM")
plt.plot(data_CFD[0]["beta"], label = "MF")
plt.xlabel("time index")
plt.ylabel("beta")
plt.legend()
plt.show()

# %%
plt.plot(data_ROM[0]["states"][:,0], label = "ROM")
plt.plot(data_CFD[0]["states"][:,0], label = "MF")
plt.xlabel("time index")
plt.ylabel("state 0")
plt.legend()
plt.show()
